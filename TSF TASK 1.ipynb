# %% [markdown]
# THE SPARKS FOUNDATION

# %% [raw]
# TASK 1 - PREDICTION USING SUPERVISED MACHINE LEARNING
# To predict the percantage of students based on their studying hours.

# %% [markdown]
# BY AKANKSHA DAS

# %%
# IMPORTING THE REQUIRED LIBRARIES.
import pandas as pd            
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# READING THE DATA.
data = pd.read_csv("http://bit.ly/w-data")
data.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# CHECKING IF THERE IS ANY NULL VALUE IN THE DATASET.
data.isnull == True
# Out:
# False

# %% [markdown]
# As there is no null value in our dataset,so,we can now visualize our data.

# %%
#PLOTTING THE DISTRIBUTION OF SCORES.
sns.set_style('darkgrid')
sns.scatterplot(y= data['Scores'], x= data['Hours'])
plt.title('Marks Vs Study Hours',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %% [markdown]
# From the above scatter plot,we can see that there is a co-relation between "Marks" and "Hours Studied".
# So,now we can plot a regression line to confirm the co-relation.

# %%
#Plotting the Regression.
sns.regplot(x= data['Hours'], y= data['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()
print(data.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# From the above regression plot we can confirm that the two(2) variables that is "Marks" and "Hours Studied" are co-related.

# %% [raw]
# Training Model

# %%
#STEP-1 : Splitting the Data.
# Defining X and y from the Data
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

# Spliting the Data in two
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %%
#STEP-2 : Fitting the Data into the model.
regression = LinearRegression()
regression.fit(train_X, train_y)
print("---------Model Trained---------")
# Out:
# ---------Model Trained---------

# %%
#Predicting the Percentage of Marks
pred_y = regression.predict(val_X)
prediction = pd.DataFrame({'Hours': [i[0] for i in val_X], 'Predicted Marks': [k for k in pred_y]})
prediction
# Out:
#    Hours  Predicted Marks
# 0    1.5        16.844722
# 1    3.2        33.745575
# 2    7.4        75.500624
# 3    2.5        26.786400
# 4    5.9        60.588106
# 5    3.8        39.710582
# 6    1.9        20.821393

# %%
#Comparing the predicted marks with actual marks.
compare_scores = pd.DataFrame({'Actual Marks': val_y, 'Predicted Marks': pred_y})
compare_scores
# Out:
#    Actual Marks  Predicted Marks
# 0            20        16.844722
# 1            27        33.745575
# 2            69        75.500624
# 3            30        26.786400
# 4            62        60.588106
# 5            35        39.710582
# 6            24        20.821393

# %%
#Visusally comparing the predicted and actual marks.
plt.scatter(x=val_X, y=val_y, color='blue')
plt.plot(val_X, pred_y, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %%
# Calculating the accuracy of the model
print('Mean absolute error: ',mean_absolute_error(val_y,pred_y))
# Out:
# Mean absolute error:  4.130879918502486

# %% [markdown]
# Small value of Mean absolute error states that the chances of error or wrong forecasting through the model are very less.

# %% [raw]
#  What will be the predicted score of a student if he/she studies for 9.25 hrs/ day?

# %%
hours = [9.25]
answer = regression.predict([hours])
print("Score = {}".format(round(answer[0],3)))
# Out:
# Score = 93.893

# %% [markdown]
# So,according to the regression model if a student studies for 9.25 hours a day he/she is likely to score 93.893 marks.
